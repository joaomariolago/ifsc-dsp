# %% [markdown]
# # Lista 3 - DSP
#
# ## Aluno
# João Mário C. I. Lago

# %%
# !pip install -q dsp-ifsc numpy pandas matplotlib

# %% [markdown]
# ## Imports

# %%
import numpy as np
from dsp_ifsc.signal import Signal
from dsp_ifsc.system import System

# %% [markdown]
# ## Ex P3.3
#
# $$
# x(n) = 2 \left(0.5\right)^n u(n + 2)
# $$

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 n = np.arange(0, 10)
#       2 x = 2.0 * Signal(0.5 ** n, n) * Signal.from_step(n, -2)
# ----> 4 x1 = x.dtft()
#       6 x1.stem()
#
# File ~/Development/Faculdade/IFSC-ELN/2024.01/ifsc-dsp-2024/lib/dsp-ifsc/dsp_ifsc/signal.py:279, in Signal.dtft(self)
#     277 fig, axs = plt.subplots(nrows=2, ncols=1)
#     278 axs[0].set_title("Resposta em magnitude 1)")
# --> 279 axs[0].plot(w/numpy.pi,numpy.abs(X))
#     280 axs[0].grid()
#     281 axs[0].set_xlabel("frequência em unidades de pi")
#
# File ~/Development/Faculdade/IFSC-ELN/2024.01/ifsc-dsp-2024/.venv/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...
